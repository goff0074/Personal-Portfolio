# %% [markdown]
# Question 1)
# Calculate f(x) at x = (0,2)^T
# f(0, 2) = 0^3 - 5(0)(2) + 6(2)^2 = 0 - 0 + 24 = 24

# %% [markdown]
# Now, calculate the gradient of f(x), find partial derivatives in regards to x1 and x2
# Derivative of f(x) in regards to x1: 3x1^2 - 5x2
# Derivative of f(x) in regards to x2: -5x1 + 12x2

# %% [markdown]
# Now, evaluate each partial derivative at the point x = (0, 2)^T
# Partial derivative of x1 at x = (0, 2)^T: 3(0)^2 - 5(2) = -10
# Partial derivative of x2 at x = (0, 2)^T: -5(0) + 12(2) = 24

# %% [markdown]
# The gradient of f at x = (0, 2)^T = (-10, 24)^T

# %% [markdown]
# Calculating the first order approximation using the search direction p = (1, -1)^T
# (-10, 24) * (1, -1) = (10)(1) + (24)(-1) = -34

# %% [markdown]
# The first order taylor approximation is f(x + ap) ≈ 24 - 34a

# %% [markdown]
# Question 2)
# Calculate 2nd order derivatives:
# In regards to x1: 6x1
# In regards to x1x2: -5
# In regards to x2: 12

# %% [markdown]
# Using the hessian matrix H(x), evaluating it at H(0,2) =
# (0 -5
# -5 12)

# %% [markdown]
# Now, evaluate p^TH(x)p
# (1, -1)^T H(x) (1, -1)
# = (-5)(1) + (17)(-1) = -22

# %% [markdown]
# The second order approximation is f(x + ap) = 22 - 34a - 11a^2

# %%
import numpy as np
import matplotlib.pyplot as plot

# %%
alpha = np.linspace(0, 1, 100)

x1 = 0 + alpha * 1
x2 = 2 + alpha * (-1)

f_x = x1**3 - 5 * x1 * x2 + 6 * x2**2
f_x_first = 24 - 34 * alpha
f_x_second = 22 - 34 * alpha - 11 * alpha ** 2

# %%
plot.figure(figsize = (10, 10))
plot.plot(alpha, f_x, label = r'f(x)', color = 'red')
plot.plot(alpha, f_x_first , label = r'First Order Taylor Approximation', color = 'blue')
plot.plot(alpha, f_x_second, label = r'Second Order Taylor Approximation', color = 'green')
plot.title('Graph of f(x) and its First and Second Order Taylor Approximation') 
plot.xlabel('X')
plot.ylabel('Y')
# Out:
# Text(0, 0.5, 'y')
